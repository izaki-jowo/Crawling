# %% [markdown]
# <a href="https://colab.research.google.com/github/izaki-jowo/Crawling/blob/main/Selamat_Datang_di_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import pandas as pd
import regex as re
drive.mount('/content/gdrive')

dataset = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/prabowo.csv')
dataset
# Out:
# Mounted at /content/gdrive
#      conversation_id_str                      created_at  favorite_count  \
# 0    1774583529990766869  Sun Mar 31 23:44:18 +0000 2024               4
# 1    1774351330825670851  Sun Mar 31 23:43:38 +0000 2024               0
# 2    1774565343761215551  Sun Mar 31 23:43:29 +0000 2024               1
# 3    1774452755496849882  Sun Mar 31 23:43:18 +0000 2024               1
# 4    1774247727406465232  Sun Mar 31 23:42:57 +0000 2024               0
# ..                   ...                             ...             ...
# 195  1774224238624530719  Sun Mar 31 21:07:41 +0000 2024               2
# 196  1774540783271694638  Sun Mar 31 20:54:26 +0000 2024               0
# 197  1774216561274101870  Sun Mar 31 20:53:35 +0000 2024              13
# 198  1774404981778698736  Sun Mar 31 20:53:12 +0000 2024               0
# 199  1774371317082628496  Sun Mar 31 20:51:57 +0000 2024               0
#
# ...

# %%
dataset.head()
# Out:
#    conversation_id_str                      created_at  favorite_count  \
# 0  1774583529990766869  Sun Mar 31 23:44:18 +0000 2024               4
# 1  1774351330825670851  Sun Mar 31 23:43:38 +0000 2024               0
# 2  1774565343761215551  Sun Mar 31 23:43:29 +0000 2024               1
# 3  1774452755496849882  Sun Mar 31 23:43:18 +0000 2024               1
# 4  1774247727406465232  Sun Mar 31 23:42:57 +0000 2024               0
#
#                                            full_text               id_str  \
# 0  banyak post april mop yaa semoga post KPU prab...  1774583529990766869
# 1  @tvOneNews Jika pak Prabowo sudah lulus uji me...  1774583362600186071
# 2  @Pencerah___ Owh sekarang bela 01 ya dulu dia ...  1774583323400208801
# 3  @natasha_k83732 @JendralKepitin9 @5teV3n_Pe9eL...  1774583276927328493
# 4            @J_D3pp hancur aja kalian zionis laknat  1774583190256275773
#
#   image_url in_reply_to_screen_name lang             location  quote_count  \
# ...

# %%
dataset.dropna(inplace=True)

# %%
dataset['full_text']
# Out:
# 32     @RaisaTjokrodnta Eh jongos buzzer 02nongol dis...
# 34     @xquitavee @prabowo Salam https://t.co/gl9SdiW9nr
# 37     @Pepatah_dr_Chin @prabowo Ini yg terdengar aud...
# 61     @RaisaTjokrodnta Jongos dongo songong nongol l...
# 100    @DedynurPalakka @gibran_tweet Ini lebih rongso...
# 143    @RaisaTjokrodnta Inilah yg nyebut Prabowo peng...
# 155    @CinereUnun41935 @Kimberley_PS08 Cacat etika G...
# Name: full_text, dtype: object

# %%
# !pip install nltk

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.tokenize import word_tokenize

# %%
pattern=r"([!@#$%^&*])"

# %%
newLines=[]
def preprocess(string):
  removePattern=re.sub(pattern," ",str(string))
  wordToken=word_tokenize(removePattern)
  removeDuplicate=list(dict.fromkeys(wordToken))
  return removeDuplicate

for lines in dataset['full_text']:
  Result=preprocess(lines)
  newLines.append(Result)

# %%
for lines in newLines:
  print(lines)
# Out:
# ['RaisaTjokrodnta', 'Eh', 'jongos', 'buzzer', '02nongol', 'disinijejak', 'digital', 'lu', 'emang', 'brutal', 'Pak', 'prabowo', 'nih', 'kurang', 'ajar', 'bgt', 'https', ':', '//t.co/cNAwAScjMP']
# ['xquitavee', 'prabowo', 'Salam', 'https', ':', '//t.co/gl9SdiW9nr']
# ['Pepatah_dr_Chin', 'prabowo', 'Ini', 'yg', 'terdengar', 'audionya', 'pak', 'https', ':', '//t.co/A7eXblkWd4']
# ['RaisaTjokrodnta', 'Jongos', 'dongo', 'songong', 'nongol', 'lagi', 'pak', 'prabowo', 'lapor', 'jongosnya', 'kurang', 'ajar', 'bgt', 'ngatain', 'bapak', 'sama', 'anak', 'dikatain', 'melambai', 'jongos', 'ga', 'tau', 'diri', 'nih', 'https', ':', '//t.co/YtT30K6jrA']
# ['DedynurPalakka', 'gibran_tweet', 'Ini', 'lebih', 'rongsokan', 'dari', 'sekedar', 'mulut', 'Prabowo', 'mesti', 'liat', 'ini', 'agar', 'hati2', 'dg', 'partai', 'Psi', 'yg', 'isi', 'programnya', 'asal', 'masuknparlemen', 'oknum2', 'Penjilat', 'dan', 'Pengadudomba', 'anak', 'bangsa', 'https', ':', '//t.co/mvbq9i8bQv']
# ...
